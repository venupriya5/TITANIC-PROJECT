# %%
'''
importing required modules  like pandas, numpys,seaborn 
 with alieas names 
'''
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\NARAYAN NANDURI\\Documents'

# %%
data=pd.read_csv('C:\\Users\\NARAYAN NANDURI\\Downloads\\Titanic-Dataset.csv')

# %%
'''
 it is used to  filll null values with maximum value 
'''
data['Embarked']=data['Embarked'].fillna(value='s').isna().sum()
data['Age']=data['Age'].fillna(value="28")
data['Embarked'].isna().sum()
data['Age'].isna().sum()
# Out:
# 0

# %%
data=pd.read_csv('C:\\Users\\NARAYAN NANDURI\\Downloads\\Titanic-Dataset.csv')
data.head(891)# accessing all data with all column names clearly so taking head and given all index number
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()   #to get all information like datatypes, and column names
data.describe() #it is used to get statical calculations
data.isnull().sum()  #it is used find sum of null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %%
data=data.drop(['Name','Ticket','Cabin'],axis=1) # to delete unwanted columns
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
''' 
for data analysis the data in sring is uncomfortable to analize, 
by using LabelEncoder transforming data in form of numerical.
'''

from sklearn import preprocessing
label_encoder =preprocessing.LabelEncoder()
data['Sex']= label_encoder.fit_transform(data['Sex'])
data["Embarked"]=label_encoder.fit_transform(data['Embarked'])
data
data['Sex'].value_counts()   #it is used to transfore sex data to male 0 and female 1
data['Embarked'].value_counts()#it is also used to tranform data to s=2,q=1,c=0 by alfabhatical order.
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0   NaN      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 9 columns]

# %%
import seaborn as sns

# %%
sns.countplot(data['Embarked'],hue=data['Survived'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sns.countplot(data['Embarked'],hue=data['Survived'])
#       2 plt.show()
#
# File ~\Downloads\New folder\lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.369226  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.093254 -0.114631
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096067  0.159651
# Embarked        0.013083 -0.163517  0.157112  0.104057 -0.025252  0.066654
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.013083
# Survived     0.081629  0.257307 -0.163517
# Pclass       0.018443 -0.549500  0.157112
# Sex         -0.245489 -0.182333  0.104057
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
data.plot(x='Survived',y=['SibSp','Parch'],kind='bar')
plt.show()

# %%
data['family']=data['SibSp']+data['Parch']+1
data=data.drop(['SibSp','Parch'],axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age     Fare  Embarked  family
# 0              1         0       3    1  22.0   7.2500         2       2
# 1              2         1       1    0  38.0  71.2833         0       2
# 2              3         1       3    0  26.0   7.9250         2       1
# 3              4         1       1    0  35.0  53.1000         2       2
# 4              5         0       3    1  35.0   8.0500         2       1
# ..           ...       ...     ...  ...   ...      ...       ...     ...
# 886          887         0       2    1  27.0  13.0000         2       1
# 887          888         1       1    0  19.0  30.0000         2       1
# 888          889         0       3    0   NaN  23.4500         2       4
# 889          890         1       1    1  26.0  30.0000         0       1
# 890          891         0       3    1  32.0   7.7500         1       1
#
# [891 rows x 8 columns]

# %%
data.plot(x='Survived',y=['family'], kind='bar')
plt.show()

# %%
plt.bar(data['Survived'],data['Fare'],color=(data['Survived']>0.0).map({True:'#A52A2A',False:'#DBB40C'}))
plt.xlabel('Survived')
plt.ylabel('Fare')
plt.gcf().set_size_inches(15,8)
plt.xticks(rotation=90)
plt.show()
